# %%
import subprocess
import numpy as np
import os
import time

# %%
def change_txt(file,init, m,r=None,s=None):
        with open(os.path.join(dir_path, file), 'r') as template_file:
            template = template_file.read()
        if r is None and s is None:
            if '_{0}d{1}_'.format(int(init), int((init-int(init))*10)) in template:
               modified_template = template.replace('{0}d{1}'.format(int(init), int((init-int(init))*10)),
                                                    '{0}d{1}'.format(int(m), int((m-int(m))*10))) 
               print('{0}d{1} replaced by {2}d{3}'.format(int(init), int((init-int(init))*10), int(m), int((m-int(m))*10)))
            elif '{0}d0'.format(init) in template:
               modified_template = template.replace('{0}d0'.format(init),
                                                    '{0}d0'.format(m)) 
               print('{0}d0 replaced by {1}d0'.format(init, m))
            else:
               print('{0}d{1} not found !!!'.format(int(init), int((init-int(init))*10)))
        elif s is not None and r is not None:
            if '{0}d{1}_{2}d{3}_{4}d{5}'.format(int(init[0]), int((init[0]-int(init[0]))*10), int(init[1]), int((init[1]-int(init[1]))*10), int(init[2]), int((init[2]-int(init[2]))*10)) in template:
               modified_template = template.replace('{0}d{1}_{2}d{3}_{4}d{5}'.format(int(init[0]), int((init[0]-int(init[0]))*10), int(init[1]), int((init[1]-int(init[1]))*10),  int(init[2]), int((init[2]-int(init[2]))*10)),
                                                    '{0}d{1}_{2}d{3}_{4}d{5}'.format(int(m), int((m-int(m))*10),int(r),int((r-int(r))*10),int(s),int((s-int(s))*10))) 
               print('{0}d{1}_{2}d{3}_{4}d{5} replaced by {6}d{7}_{8}d{9}_{10}d{11}'.format(int(init[0]), int((init[0]-int(init[0]))*10), int(init[1]), int((init[1]-int(init[1]))*10), int(init[2]), int((init[2]-int(init[2]))*10),
                                                                                            int(m), int((m-int(m))*10),int(r),int((r-int(r))*10),int(s),int((s-int(s))*10)))  
            else:
               print('{0}d{1}_{2}d{3}_{4}d{5} not found !!!'.format(int(init[0]), int((init[0]-int(init[0]))*10), int(init[1]), int((init[1]-int(init[1]))*10), int(init[2]), int((init[2]-int(init[2]))*10)))
        else:
            print('check your inlist files')
        with open(os.path.join(dir_path, file), 'w') as modified_file:
           modified_file.write(modified_template)

# %%
dir_path = '/home/maxwav/Software/MESA/mesa-r11554/star/test_suite/KLENCKI_models/NGC45_Nadia/'

# %% [markdown]
# # Change mass_d, mass_a, bin_sep

# %%
initial_mass = [k for k in np.arange(21, 22, 0.5)]
initial_ratio = [k for k in np.arange(3.7, 4.1, 0.15)]
bin_sep = [k for k in np.arange(1100, 1250, 100)]
combinations = [(i, np.round(i/j,2), k) for i in initial_mass for j in initial_ratio for k in bin_sep]

print(combinations)
init = [18,4,400]
init1 = 18
init2 = 4
init3 = 400
count=1
dir_path = '/home/maxwav/Software/MESA/mesa-r11554/star/test_suite/KLENCKI_models/NGC45_Nadia/'

for m,r,s in combinations:
        print(m,r,s)
        
        change_txt('star_job_extra', init1, m, None, None)
        # change_txt('star_job_extra', init, m, r, s)
        change_txt('inlist1', init, m, r, s)
        change_txt('inlist_extra_binary', init2, r, None, None)
        change_txt('inlist_extra_binary', init3, s, None, None)
        init = [m,r,s]
        init1 = m
        init2 = r
        init3 = s

        subprocess.run(['cd', dir_path], shell=True, check=True)
        subprocess.run(['pwd'], shell=True, check=True)
        print("we are located in {0}".format(dir_path))
    
        print("Environment:",os.environ.get('MESA_DIR'), "\n",os.environ.get('MESASDK_ROOT'))
    
        # Run clean and mk executables
        print(os.chdir(dir_path))
        print(" \n ****************************** \n **Software/MESA/mesa-r11554/star/** \n ****************************** \n \n \n  /!\ /!\ /!\ Run {0}/{1} with mass_donor={2} mass_accretor={3} bin_sep={4}  /!\ /!\ /!\ \n \n \n ****************************** \n ****************************** \n ".format(count, len(combinations),m,r,s))
        print(" Time: {0}".format(time.strftime("%Y-%m-%d %H:%M:%S", time.localtime())))
        print("start cleaning, making and running")
        process = subprocess.run(['./clean; ./mk; ./rn', dir_path], stdout=subprocess.PIPE, text=True, shell=True, check=True)
        print("clean, make and run done")
        output = process.stdout.splitlines()
        for line in output[:10]:
            print(line)
        count+=1
# Out:
# [(19.5, 5.0, 1200), (19.5, 5.0, 1400), (19.5, 4.76, 1200), (19.5, 4.76, 1400), (20.0, 5.13, 1200), (20.0, 5.13, 1400), (20.0, 4.88, 1200), (20.0, 4.88, 1400), (20.5, 5.26, 1200), (20.5, 5.26, 1400), (20.5, 5.0, 1200), (20.5, 5.0, 1400)]
# 19.5 5.0 1200
# 18d0 replaced by 19d5
# 18d0_4d0_400d0 replaced by 19d5_5d0_1200d0
# 4d0 replaced by 5.0d0
# 400d0 replaced by 1200d0
# /home/maxwav/MESA_modeling/MESA_codes
# we are located in /home/maxwav/Software/MESA/mesa-r11554/star/test_suite/KLENCKI_models/NGC45_Nadia/
# Environment: /home/maxwav/Software/MESA/mesa-r11554
#  /home/maxwav/Software/MESA/mesasdk_r11554/mesasdk
# None
#
#  ******************************
#  **Software/MESA/mesa-r11554/star/**
#  ******************************
#
#
#   /!\ /!\ /!\ Run 1/12 with mass_donor=19.5 mass_accretor=5.0 bin_sep=1200  /!\ /!\ /!\
#
#
#  ******************************
#  ******************************
#
#  Time: 2023-12-21 00:06:14
# start cleaning, making and running
# PGPLOT /xw: cannot connect to X server []
# clean, make and run done
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/run_star_extras.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/run_binary_extras.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c /home/maxwav/Software/MESA/mesa-r11554/binary/job/run_binary.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/binary_run.f
# gfortran -fopenmp -o ../binary run_star_extras.o run_binary_extras.o run_binary.o binary_run.o  -L/home/maxwav/Software/MESA/mesa-r11554/lib -lbinary -lstar -lionization -latm -lcolors -lnet -leos -lkap -lrates -lneu -lchem -linterp_2d -linterp_1d -lnum -lf2crlibm -lcrlibm -lmtx -lconst -lutils `mesasdk_lapack_link` `mesasdk_blas_link` `mesasdk_hdf5_link` -lgyre  `mesasdk_pgplot_link` -lz
# DATE: 2023-12-21
# TIME: 00:06:18
#
#
#  read inlist_project
# 19.5 5.0 1400
# 19d5 replaced by 19d5
# 19d5_5d0_1200d0 replaced by 19d5_5d0_1400d0
# 5.0d0 replaced by 5.0d0
# 1200d0 replaced by 1400d0
# /home/maxwav/Software/MESA/mesa-r11554/star/test_suite/KLENCKI_models/NGC45_Nadia
# we are located in /home/maxwav/Software/MESA/mesa-r11554/star/test_suite/KLENCKI_models/NGC45_Nadia/
# Environment: /home/maxwav/Software/MESA/mesa-r11554
#  /home/maxwav/Software/MESA/mesasdk_r11554/mesasdk
# None
#
#  ******************************
#  **Software/MESA/mesa-r11554/star/**
#  ******************************
#
#
#   /!\ /!\ /!\ Run 2/12 with mass_donor=19.5 mass_accretor=5.0 bin_sep=1400  /!\ /!\ /!\
#
#
#  ******************************
#  ******************************
#
#  Time: 2023-12-21 00:28:22
# start cleaning, making and running
# PGPLOT /xw: cannot connect to X server []
# clean, make and run done
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/run_star_extras.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/run_binary_extras.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c /home/maxwav/Software/MESA/mesa-r11554/binary/job/run_binary.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/binary_run.f
# gfortran -fopenmp -o ../binary run_star_extras.o run_binary_extras.o run_binary.o binary_run.o  -L/home/maxwav/Software/MESA/mesa-r11554/lib -lbinary -lstar -lionization -latm -lcolors -lnet -leos -lkap -lrates -lneu -lchem -linterp_2d -linterp_1d -lnum -lf2crlibm -lcrlibm -lmtx -lconst -lutils `mesasdk_lapack_link` `mesasdk_blas_link` `mesasdk_hdf5_link` -lgyre  `mesasdk_pgplot_link` -lz
# DATE: 2023-12-21
# TIME: 00:28:25
#
#
#  read inlist_project
# 19.5 4.76 1200
# 19d5 replaced by 19d5
# 19d5_5d0_1400d0 replaced by 19d5_4d7_1200d0
# 5.0d0 replaced by 4.76d0
# 1400d0 replaced by 1200d0
# /home/maxwav/Software/MESA/mesa-r11554/star/test_suite/KLENCKI_models/NGC45_Nadia
# we are located in /home/maxwav/Software/MESA/mesa-r11554/star/test_suite/KLENCKI_models/NGC45_Nadia/
# Environment: /home/maxwav/Software/MESA/mesa-r11554
#  /home/maxwav/Software/MESA/mesasdk_r11554/mesasdk
# None
#
#  ******************************
#  **Software/MESA/mesa-r11554/star/**
#  ******************************
#
#
#   /!\ /!\ /!\ Run 3/12 with mass_donor=19.5 mass_accretor=4.76 bin_sep=1200  /!\ /!\ /!\
#
#
#  ******************************
#  ******************************
#
#  Time: 2023-12-21 00:50:01
# start cleaning, making and running
# PGPLOT /xw: cannot connect to X server []
# clean, make and run done
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/run_star_extras.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/run_binary_extras.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c /home/maxwav/Software/MESA/mesa-r11554/binary/job/run_binary.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/binary_run.f
# gfortran -fopenmp -o ../binary run_star_extras.o run_binary_extras.o run_binary.o binary_run.o  -L/home/maxwav/Software/MESA/mesa-r11554/lib -lbinary -lstar -lionization -latm -lcolors -lnet -leos -lkap -lrates -lneu -lchem -linterp_2d -linterp_1d -lnum -lf2crlibm -lcrlibm -lmtx -lconst -lutils `mesasdk_lapack_link` `mesasdk_blas_link` `mesasdk_hdf5_link` -lgyre  `mesasdk_pgplot_link` -lz
# DATE: 2023-12-21
# TIME: 00:50:05
#
#
#  read inlist_project
# 19.5 4.76 1400
# 19d5 replaced by 19d5
# 19d5_4d7_1200d0 replaced by 19d5_4d7_1400d0
# 4.76d0 replaced by 4.76d0
# 1200d0 replaced by 1400d0
# /home/maxwav/Software/MESA/mesa-r11554/star/test_suite/KLENCKI_models/NGC45_Nadia
# we are located in /home/maxwav/Software/MESA/mesa-r11554/star/test_suite/KLENCKI_models/NGC45_Nadia/
# Environment: /home/maxwav/Software/MESA/mesa-r11554
#  /home/maxwav/Software/MESA/mesasdk_r11554/mesasdk
# None
#
#  ******************************
#  **Software/MESA/mesa-r11554/star/**
#  ******************************
#
#
#   /!\ /!\ /!\ Run 4/12 with mass_donor=19.5 mass_accretor=4.76 bin_sep=1400  /!\ /!\ /!\
#
#
#  ******************************
#  ******************************
#
#  Time: 2023-12-21 01:12:28
# start cleaning, making and running
# PGPLOT /xw: cannot connect to X server []
# clean, make and run done
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/run_star_extras.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/run_binary_extras.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c /home/maxwav/Software/MESA/mesa-r11554/binary/job/run_binary.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/binary_run.f
# gfortran -fopenmp -o ../binary run_star_extras.o run_binary_extras.o run_binary.o binary_run.o  -L/home/maxwav/Software/MESA/mesa-r11554/lib -lbinary -lstar -lionization -latm -lcolors -lnet -leos -lkap -lrates -lneu -lchem -linterp_2d -linterp_1d -lnum -lf2crlibm -lcrlibm -lmtx -lconst -lutils `mesasdk_lapack_link` `mesasdk_blas_link` `mesasdk_hdf5_link` -lgyre  `mesasdk_pgplot_link` -lz
# DATE: 2023-12-21
# TIME: 01:12:32
#
#
#  read inlist_project
# 20.0 5.13 1200
# 19d5 replaced by 20d0
# 19d5_4d7_1400d0 replaced by 20d0_5d1_1200d0
# 4.76d0 replaced by 5.13d0
# 1400d0 replaced by 1200d0
# /home/maxwav/Software/MESA/mesa-r11554/star/test_suite/KLENCKI_models/NGC45_Nadia
# we are located in /home/maxwav/Software/MESA/mesa-r11554/star/test_suite/KLENCKI_models/NGC45_Nadia/
# Environment: /home/maxwav/Software/MESA/mesa-r11554
#  /home/maxwav/Software/MESA/mesasdk_r11554/mesasdk
# None
#
#  ******************************
#  **Software/MESA/mesa-r11554/star/**
#  ******************************
#
#
#   /!\ /!\ /!\ Run 5/12 with mass_donor=20.0 mass_accretor=5.13 bin_sep=1200  /!\ /!\ /!\
#
#
#  ******************************
#  ******************************
#
#  Time: 2023-12-21 01:35:06
# start cleaning, making and running
# PGPLOT /xw: cannot connect to X server []
# clean, make and run done
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/run_star_extras.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/run_binary_extras.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c /home/maxwav/Software/MESA/mesa-r11554/binary/job/run_binary.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/binary_run.f
# gfortran -fopenmp -o ../binary run_star_extras.o run_binary_extras.o run_binary.o binary_run.o  -L/home/maxwav/Software/MESA/mesa-r11554/lib -lbinary -lstar -lionization -latm -lcolors -lnet -leos -lkap -lrates -lneu -lchem -linterp_2d -linterp_1d -lnum -lf2crlibm -lcrlibm -lmtx -lconst -lutils `mesasdk_lapack_link` `mesasdk_blas_link` `mesasdk_hdf5_link` -lgyre  `mesasdk_pgplot_link` -lz
# DATE: 2023-12-21
# TIME: 01:35:10
#
#
#  read inlist_project
# 20.0 5.13 1400
# 20d0 replaced by 20d0
# 20d0_5d1_1200d0 replaced by 20d0_5d1_1400d0
# 5.13d0 replaced by 5.13d0
# 1200d0 replaced by 1400d0
# /home/maxwav/Software/MESA/mesa-r11554/star/test_suite/KLENCKI_models/NGC45_Nadia
# we are located in /home/maxwav/Software/MESA/mesa-r11554/star/test_suite/KLENCKI_models/NGC45_Nadia/
# Environment: /home/maxwav/Software/MESA/mesa-r11554
#  /home/maxwav/Software/MESA/mesasdk_r11554/mesasdk
# None
#
#  ******************************
#  **Software/MESA/mesa-r11554/star/**
#  ******************************
#
#
#   /!\ /!\ /!\ Run 6/12 with mass_donor=20.0 mass_accretor=5.13 bin_sep=1400  /!\ /!\ /!\
#
#
#  ******************************
#  ******************************
#
#  Time: 2023-12-21 01:57:10
# start cleaning, making and running
# PGPLOT /xw: cannot connect to X server []
# clean, make and run done
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/run_star_extras.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/run_binary_extras.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c /home/maxwav/Software/MESA/mesa-r11554/binary/job/run_binary.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/binary_run.f
# gfortran -fopenmp -o ../binary run_star_extras.o run_binary_extras.o run_binary.o binary_run.o  -L/home/maxwav/Software/MESA/mesa-r11554/lib -lbinary -lstar -lionization -latm -lcolors -lnet -leos -lkap -lrates -lneu -lchem -linterp_2d -linterp_1d -lnum -lf2crlibm -lcrlibm -lmtx -lconst -lutils `mesasdk_lapack_link` `mesasdk_blas_link` `mesasdk_hdf5_link` -lgyre  `mesasdk_pgplot_link` -lz
# DATE: 2023-12-21
# TIME: 01:57:13
#
#
#  read inlist_project
# 20.0 4.88 1200
# 20d0 replaced by 20d0
# 20d0_5d1_1400d0 replaced by 20d0_4d8_1200d0
# 5.13d0 replaced by 4.88d0
# 1400d0 replaced by 1200d0
# /home/maxwav/Software/MESA/mesa-r11554/star/test_suite/KLENCKI_models/NGC45_Nadia
# we are located in /home/maxwav/Software/MESA/mesa-r11554/star/test_suite/KLENCKI_models/NGC45_Nadia/
# Environment: /home/maxwav/Software/MESA/mesa-r11554
#  /home/maxwav/Software/MESA/mesasdk_r11554/mesasdk
# None
#
#  ******************************
#  **Software/MESA/mesa-r11554/star/**
#  ******************************
#
#
#   /!\ /!\ /!\ Run 7/12 with mass_donor=20.0 mass_accretor=4.88 bin_sep=1200  /!\ /!\ /!\
#
#
#  ******************************
#  ******************************
#
#  Time: 2023-12-21 02:20:23
# start cleaning, making and running
# PGPLOT /xw: cannot connect to X server []
# clean, make and run done
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/run_star_extras.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/run_binary_extras.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c /home/maxwav/Software/MESA/mesa-r11554/binary/job/run_binary.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/binary_run.f
# gfortran -fopenmp -o ../binary run_star_extras.o run_binary_extras.o run_binary.o binary_run.o  -L/home/maxwav/Software/MESA/mesa-r11554/lib -lbinary -lstar -lionization -latm -lcolors -lnet -leos -lkap -lrates -lneu -lchem -linterp_2d -linterp_1d -lnum -lf2crlibm -lcrlibm -lmtx -lconst -lutils `mesasdk_lapack_link` `mesasdk_blas_link` `mesasdk_hdf5_link` -lgyre  `mesasdk_pgplot_link` -lz
# DATE: 2023-12-21
# TIME: 02:20:27
#
#
#  read inlist_project
# 20.0 4.88 1400
# 20d0 replaced by 20d0
# 20d0_4d8_1200d0 replaced by 20d0_4d8_1400d0
# 4.88d0 replaced by 4.88d0
# 1200d0 replaced by 1400d0
# /home/maxwav/Software/MESA/mesa-r11554/star/test_suite/KLENCKI_models/NGC45_Nadia
# we are located in /home/maxwav/Software/MESA/mesa-r11554/star/test_suite/KLENCKI_models/NGC45_Nadia/
# Environment: /home/maxwav/Software/MESA/mesa-r11554
#  /home/maxwav/Software/MESA/mesasdk_r11554/mesasdk
# None
#
#  ******************************
#  **Software/MESA/mesa-r11554/star/**
#  ******************************
#
#
#   /!\ /!\ /!\ Run 8/12 with mass_donor=20.0 mass_accretor=4.88 bin_sep=1400  /!\ /!\ /!\
#
#
#  ******************************
#  ******************************
#
#  Time: 2023-12-21 02:44:08
# start cleaning, making and running
# PGPLOT /xw: cannot connect to X server []
# clean, make and run done
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/run_star_extras.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/run_binary_extras.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c /home/maxwav/Software/MESA/mesa-r11554/binary/job/run_binary.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/binary_run.f
# gfortran -fopenmp -o ../binary run_star_extras.o run_binary_extras.o run_binary.o binary_run.o  -L/home/maxwav/Software/MESA/mesa-r11554/lib -lbinary -lstar -lionization -latm -lcolors -lnet -leos -lkap -lrates -lneu -lchem -linterp_2d -linterp_1d -lnum -lf2crlibm -lcrlibm -lmtx -lconst -lutils `mesasdk_lapack_link` `mesasdk_blas_link` `mesasdk_hdf5_link` -lgyre  `mesasdk_pgplot_link` -lz
# DATE: 2023-12-21
# TIME: 02:44:11
#
#
#  read inlist_project
# 20.5 5.26 1200
# 20d0 replaced by 20d5
# 20d0_4d8_1400d0 replaced by 20d5_5d2_1200d0
# 4.88d0 replaced by 5.26d0
# 1400d0 replaced by 1200d0
# /home/maxwav/Software/MESA/mesa-r11554/star/test_suite/KLENCKI_models/NGC45_Nadia
# we are located in /home/maxwav/Software/MESA/mesa-r11554/star/test_suite/KLENCKI_models/NGC45_Nadia/
# Environment: /home/maxwav/Software/MESA/mesa-r11554
#  /home/maxwav/Software/MESA/mesasdk_r11554/mesasdk
# None
#
#  ******************************
#  **Software/MESA/mesa-r11554/star/**
#  ******************************
#
#
#   /!\ /!\ /!\ Run 9/12 with mass_donor=20.5 mass_accretor=5.26 bin_sep=1200  /!\ /!\ /!\
#
#
#  ******************************
#  ******************************
#
#  Time: 2023-12-21 03:06:49
# start cleaning, making and running
# PGPLOT /xw: cannot connect to X server []
# clean, make and run done
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/run_star_extras.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/run_binary_extras.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c /home/maxwav/Software/MESA/mesa-r11554/binary/job/run_binary.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/binary_run.f
# gfortran -fopenmp -o ../binary run_star_extras.o run_binary_extras.o run_binary.o binary_run.o  -L/home/maxwav/Software/MESA/mesa-r11554/lib -lbinary -lstar -lionization -latm -lcolors -lnet -leos -lkap -lrates -lneu -lchem -linterp_2d -linterp_1d -lnum -lf2crlibm -lcrlibm -lmtx -lconst -lutils `mesasdk_lapack_link` `mesasdk_blas_link` `mesasdk_hdf5_link` -lgyre  `mesasdk_pgplot_link` -lz
# DATE: 2023-12-21
# TIME: 03:06:52
#
#
#  read inlist_project
# 20.5 5.26 1400
# 20d5 replaced by 20d5
# 20d5_5d2_1200d0 replaced by 20d5_5d2_1400d0
# 5.26d0 replaced by 5.26d0
# 1200d0 replaced by 1400d0
# /home/maxwav/Software/MESA/mesa-r11554/star/test_suite/KLENCKI_models/NGC45_Nadia
# we are located in /home/maxwav/Software/MESA/mesa-r11554/star/test_suite/KLENCKI_models/NGC45_Nadia/
# Environment: /home/maxwav/Software/MESA/mesa-r11554
#  /home/maxwav/Software/MESA/mesasdk_r11554/mesasdk
# None
#
#  ******************************
#  **Software/MESA/mesa-r11554/star/**
#  ******************************
#
#
#   /!\ /!\ /!\ Run 10/12 with mass_donor=20.5 mass_accretor=5.26 bin_sep=1400  /!\ /!\ /!\
#
#
#  ******************************
#  ******************************
#
#  Time: 2023-12-21 03:30:06
# start cleaning, making and running
# PGPLOT /xw: cannot connect to X server []
# clean, make and run done
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/run_star_extras.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/run_binary_extras.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c /home/maxwav/Software/MESA/mesa-r11554/binary/job/run_binary.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/binary_run.f
# gfortran -fopenmp -o ../binary run_star_extras.o run_binary_extras.o run_binary.o binary_run.o  -L/home/maxwav/Software/MESA/mesa-r11554/lib -lbinary -lstar -lionization -latm -lcolors -lnet -leos -lkap -lrates -lneu -lchem -linterp_2d -linterp_1d -lnum -lf2crlibm -lcrlibm -lmtx -lconst -lutils `mesasdk_lapack_link` `mesasdk_blas_link` `mesasdk_hdf5_link` -lgyre  `mesasdk_pgplot_link` -lz
# DATE: 2023-12-21
# TIME: 03:30:09
#
#
#  read inlist_project
# 20.5 5.0 1200
# 20d5 replaced by 20d5
# 20d5_5d2_1400d0 replaced by 20d5_5d0_1200d0
# 5.26d0 replaced by 5.0d0
# 1400d0 replaced by 1200d0
# /home/maxwav/Software/MESA/mesa-r11554/star/test_suite/KLENCKI_models/NGC45_Nadia
# we are located in /home/maxwav/Software/MESA/mesa-r11554/star/test_suite/KLENCKI_models/NGC45_Nadia/
# Environment: /home/maxwav/Software/MESA/mesa-r11554
#  /home/maxwav/Software/MESA/mesasdk_r11554/mesasdk
# None
#
#  ******************************
#  **Software/MESA/mesa-r11554/star/**
#  ******************************
#
#
#   /!\ /!\ /!\ Run 11/12 with mass_donor=20.5 mass_accretor=5.0 bin_sep=1200  /!\ /!\ /!\
#
#
#  ******************************
#  ******************************
#
#  Time: 2023-12-21 03:53:07
# start cleaning, making and running
# PGPLOT /xw: cannot connect to X server []
# clean, make and run done
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/run_star_extras.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/run_binary_extras.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c /home/maxwav/Software/MESA/mesa-r11554/binary/job/run_binary.f
# gfortran -Wno-uninitialized -fno-range-check -fmax-errors=7  -fprotect-parens -fno-sign-zero -fbacktrace -ggdb -finit-real=snan -fopenmp -fbounds-check -Wuninitialized -Warray-bounds -ggdb -ffree-form -x f95-cpp-input -I/home/maxwav/Software/MESA/mesa-r11554/include -I/home/maxwav/Software/MESA/mesasdk_r11554/mesasdk/include -c ../src/binary_run.f
# gfortran -fopenmp -o ../binary run_star_extras.o run_binary_extras.o run_binary.o binary_run.o  -L/home/maxwav/Software/MESA/mesa-r11554/lib -lbinary -lstar -lionization -latm -lcolors -lnet -leos -lkap -lrates -lneu -lchem -linterp_2d -linterp_1d -lnum -lf2crlibm -lcrlibm -lmtx -lconst -lutils `mesasdk_lapack_link` `mesasdk_blas_link` `mesasdk_hdf5_link` -lgyre  `mesasdk_pgplot_link` -lz
# DATE: 2023-12-21
# TIME: 03:53:10
#
#
#  read inlist_project
# 20.5 5.0 1400
# 20d5 replaced by 20d5
# 20d5_5d0_1200d0 replaced by 20d5_5d0_1400d0
# 5.0d0 replaced by 5.0d0
# 1200d0 replaced by 1400d0
# /home/maxwav/Software/MESA/mesa-r11554/star/test_suite/KLENCKI_models/NGC45_Nadia
# we are located in /home/maxwav/Software/MESA/mesa-r11554/star/test_suite/KLENCKI_models/NGC45_Nadia/
# Environment: /home/maxwav/Software/MESA/mesa-r11554
#  /home/maxwav/Software/MESA/mesasdk_r11554/mesasdk
# None
#
#  ******************************
#  **Software/MESA/mesa-r11554/star/**
#  ******************************
#
#
#   /!\ /!\ /!\ Run 12/12 with mass_donor=20.5 mass_accretor=5.0 bin_sep=1400  /!\ /!\ /!\
#
#
#  ******************************
#  ******************************
#
#  Time: 2023-12-21 04:17:37
# start cleaning, making and running
# PGPLOT /xw: cannot connect to X server []

# %%
subprocess.Popen('Jakub', shell=True, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
